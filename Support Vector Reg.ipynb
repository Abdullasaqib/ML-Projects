# %% [markdown]
# ### Step 1: Importing The Libraries

# %%
import sklearn
import pandas as pd

# %% [markdown]
# ### Step 2: Importing The Data

# %%
df = pd.read_csv(r"D:\Datasets\Machine Learning\tip.csv")

# %% [markdown]
# ### Step 3: Data Preprocessing/ Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
Encoder = LabelEncoder()
df['gender'] = Encoder.fit_transform(df['sex'])
df.drop(columns='sex', inplace=True)
df['smoker'] = Encoder.fit_transform(df['smoker'])
df['day'] = Encoder.fit_transform(df['day'])
df['time'] = Encoder.fit_transform(df['time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   smoker      244 non-null    int32
#  3   day         244 non-null    int32
#  4   time        244 non-null    int32
#  5   size        244 non-null    int64
#  6   gender      244 non-null    int32
# dtypes: float64(2), int32(4), int64(1)
# memory usage: 9.7 KB

# %% [markdown]
# ### Step 4: Splitting The Data

# %%
A = df.drop(columns='tip')
b = df['tip']

# %%
from sklearn.model_selection import train_test_split
A_train, A_test, b_train, b_test = train_test_split(A, b, test_size=0.12, random_state=7)

# %% [markdown]
# ### Step 5: Building The Model & 5.1: Initilizing The Model

# %%
from sklearn.svm import SVR
vector_model = SVR()

# %% [markdown]
# ### Step 5.2: Training The Model

# %%
vector_model.fit(A_train,b_train)
# Out:
# SVR()

# %% [markdown]
# ### Step 5.3: Predicting From The Model

# %%
b_pred = vector_model.predict(A_test)

# %% [markdown]
# ### Step 5.4: Testing The Model

# %%
from sklearn.metrics import r2_score, mean_squared_error
print(r2_score(b_pred,b_test)*100)
print(mean_squared_error(b_pred,b_test)**0.5)
# Out:
# 31.77297979971859
# 0.8030431579009513
